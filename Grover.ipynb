# %%
def keyexpinverse(qc):
    qc.cx(k[5],k[2])
    qc.cx(k[4],k[1])
    qc.cx(k[3],k[0])

    qc.cx(k[2],k[1])
    qc.cx(k[1],k[2])
    qc.cx(k[2],k[1])
    qc.cx(k[1],k[0])
    qc.cx(k[0],k[1])
    qc.cx(k[1],k[0])

    qc.cx(k[2],k[5])
    qc.cx(k[1],k[4])
    qc.cx(k[0],k[3])

    qc.cx(k[1],k[2])

    qc.ccx(k[3],k[0],k[1])
    qc.cx(k[1],k[4])
    qc.ccx(k[4],k[1],k[2])
    qc.cx(k[2],k[5])

    qc.ccx(k[5],k[2],anc[0])
    qc.ccx(k[4],k[1],k[2])
    qc.ccx(k[3],k[0],k[1])

    qc.cx(k[1],k[2])
    qc.cx(k[2],anc[0])

    qc.cx(k[2],k[5])
    qc.cx(k[1],k[4])

    qc.cx(k[4],k[3])
    qc.cx(k[3],k[4])
    qc.cx(k[4],k[3])
    qc.cx(k[5],k[4])
    qc.cx(k[4],k[5])
    qc.cx(k[5],k[4])
    
def keyexpansion(qc):
    qc.cx(k[5],k[4])
    qc.cx(k[4],k[5])
    qc.cx(k[5],k[4])
    qc.cx(k[4],k[3])
    qc.cx(k[3],k[4])
    qc.cx(k[4],k[3])

    qc.cx(k[1],k[4])
    qc.cx(k[2],k[5])

    qc.cx(k[2],anc[0])
    qc.cx(k[1],k[2])

    qc.ccx(k[3],k[0],k[1])
    qc.ccx(k[4],k[1],k[2])
    qc.ccx(k[5],k[2],anc[0])

    qc.cx(k[2],k[5])
    qc.ccx(k[4],k[1],k[2])
    qc.cx(k[1],k[4])
    qc.ccx(k[3],k[0],k[1])

    qc.cx(k[1],k[2])

    qc.cx(k[0],k[3])
    qc.cx(k[1],k[4])
    qc.cx(k[2],k[5])

    qc.cx(k[1],k[0])
    qc.cx(k[0],k[1])
    qc.cx(k[1],k[0])
    qc.cx(k[2],k[1])
    qc.cx(k[1],k[2])
    qc.cx(k[2],k[1])

    qc.cx(k[3],k[0])
    qc.cx(k[4],k[1])
    qc.cx(k[5],k[2])
    
def roundupdate(qc):
    qc.cx(l[2],l[1])
    qc.cx(l[1],l[2])
    qc.cx(l[2],l[1])
    qc.cx(l[1],l[0])
    qc.cx(l[0],l[1])
    qc.cx(l[1],l[0])

    qc.cx(l[4],l[1])
    qc.cx(l[5],l[2])
    
    qc.cx(l[5],anc[0])
    qc.cx(l[4],l[5])
    
    qc.ccx(l[0],l[3],l[4])
    qc.ccx(l[1],l[4],l[5])
    qc.ccx(l[2],l[5],anc[0])
    
    qc.cx(l[5],l[2])
    qc.ccx(l[1],l[4],l[5])
    
    qc.cx(l[4],l[1])
    qc.ccx(l[0],l[3],l[4])
    
    qc.cx(l[4],l[5])
    
    qc.cx(l[3],l[0])
    qc.cx(l[4],l[1])
    qc.cx(l[5],l[2])

    qc.cx(k[0],l[0])
    qc.cx(k[1],l[1])
    qc.cx(k[2],l[2])

    qc.cx(l[4],l[3])
    qc.cx(l[3],l[4])
    qc.cx(l[4],l[3])
    qc.cx(l[5],l[4])
    qc.cx(l[4],l[5])
    qc.cx(l[5],l[4])

    qc.cx(l[0],l[3])
    qc.cx(l[1],l[4])
    qc.cx(l[2],l[5])
    
def roundupinverse(qc):
    qc.cx(l[2],l[5])
    qc.cx(l[1],l[4])
    qc.cx(l[0],l[3])
    
    qc.cx(l[5],l[4])
    qc.cx(l[4],l[5])
    qc.cx(l[5],l[4])
    qc.cx(l[4],l[3])
    qc.cx(l[3],l[4])
    qc.cx(l[4],l[3])
    
    qc.cx(k[2],l[2])
    qc.cx(k[1],l[1])
    qc.cx(k[0],l[0])
    
    qc.cx(l[5],l[2])
    qc.cx(l[4],l[1])
    qc.cx(l[3],l[0])
    
    qc.cx(l[4],l[5])
    
    qc.ccx(l[0],l[3],l[4])
    qc.cx(l[4],l[1])
    
    qc.ccx(l[1],l[4],l[5])
    qc.cx(l[5],l[2])
    
    qc.ccx(l[2],l[5],anc[0])
    qc.ccx(l[1],l[4],l[5])
    qc.ccx(l[0],l[3],l[4])
    
    qc.cx(l[4],l[5])
    qc.cx(l[5],anc[0])
    
    qc.cx(l[5],l[2])
    qc.cx(l[4],l[1])
    
    qc.cx(l[1],l[0])
    qc.cx(l[0],l[1])
    qc.cx(l[1],l[0])
    qc.cx(l[2],l[1])
    qc.cx(l[1],l[2])
    qc.cx(l[2],l[1])
    
    
def stateupdate(qc):
    qc.x(l[1])
    qc.x(l[2])
    qc.x(l[3])
    qc.x(l[4])
    qc.x(l[5])
    roundupdate(qc)
    keyexpansion(qc)
    roundupdate(qc)
    
def stateupinverse(qc):
    roundupinverse(qc)
    keyexpinverse(qc)
    roundupinverse(qc)
    qc.x(l[1])
    qc.x(l[2])
    qc.x(l[3])
    qc.x(l[4])
    qc.x(l[5])
    
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

n=6
l = QuantumRegister(n, name = 'l')
k = QuantumRegister(n,name = 'k')
anc = QuantumRegister(1,name = 'anc')
trg = QuantumRegister(1, name = 'trg')
anc1 = QuantumRegister(n-2, name = 'anc1')
cl = ClassicalRegister(n, name='cl')
qc = QuantumCircuit(l,k,anc,trg,anc1,cl)

for i in range(n):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(n):
    stateupdate(qc)
    oq.Grover_Oracle([1,0,1,1,0,1], qc, l, trg, anc1)
    stateupinverse(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc1)


for i in range(n):
    qc.measure(k[i],cl[i])
        
job = execute(qc, simulator, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
